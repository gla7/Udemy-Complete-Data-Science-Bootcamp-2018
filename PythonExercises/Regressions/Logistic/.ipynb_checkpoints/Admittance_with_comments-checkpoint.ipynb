# %% [markdown]
# # Basics of logistic regression

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /Users/gleon/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Load the data

# %%
raw_data = pd.read_csv('2.01. Admittance.csv')
raw_data
# Out:
#       SAT Admitted
# 0    1363       No
# 1    1792      Yes
# 2    1954      Yes
# 3    1653       No
# 4    1593       No
# 5    1755      Yes
# 6    1775      Yes
# 7    1887      Yes
# 8    1893      Yes
# 9    1580       No
# 10   1857      Yes
# 11   1880      Yes
# 12   1664      Yes
# 13   1364       No
# 14   1693       No
# 15   1850      Yes
# 16   1633       No
# 17   1634       No
# 18   1636      Yes
# 19   1855      Yes
# 20   1987      Yes
# 21   1997      Yes
# 22   1422       No
# 23   1508       No
# 24   1720      Yes
# 25   1879      Yes
# 26   1634      Yes
# 27   1802      Yes
# 28   1849      Yes
# 29   1764      Yes
# ..    ...      ...
# 138  1412       No
# 139  1557       No
# 140  1821      Yes
# 141  1760      Yes
# 142  1685      Yes
# 143  1773      Yes
# 144  1826      Yes
# 145  1565       No
# 146  1510       No
# 147  1374       No
# 148  1402       No
# 149  1702      Yes
# 150  1956      Yes
# 151  1933      Yes
# 152  1832      Yes
# ...

# %%
# Replace all No entries with 0, and all Yes entries with 1
data = raw_data.copy()
data['Admitted'] = data['Admitted'].map({'Yes': 1, 'No': 0})
data
# Out:
#       SAT  Admitted
# 0    1363         0
# 1    1792         1
# 2    1954         1
# 3    1653         0
# 4    1593         0
# 5    1755         1
# 6    1775         1
# 7    1887         1
# 8    1893         1
# 9    1580         0
# 10   1857         1
# 11   1880         1
# 12   1664         1
# 13   1364         0
# 14   1693         0
# 15   1850         1
# 16   1633         0
# 17   1634         0
# 18   1636         1
# 19   1855         1
# 20   1987         1
# 21   1997         1
# 22   1422         0
# 23   1508         0
# 24   1720         1
# 25   1879         1
# 26   1634         1
# 27   1802         1
# 28   1849         1
# 29   1764         1
# ..    ...       ...
# 138  1412         0
# 139  1557         0
# 140  1821         1
# 141  1760         1
# 142  1685         1
# 143  1773         1
# 144  1826         1
# 145  1565         0
# 146  1510         0
# 147  1374         0
# 148  1402         0
# 149  1702         1
# 150  1956         1
# ...

# %% [markdown]
# ## Variables

# %%
# Create the dependent and independent variables
y = data['Admitted']
x1 = data['SAT']

# %% [markdown]
# ## Let's plot the data

# %% [markdown]
# ### Scatter plot

# %%
# Create a scatter plot of x1 (SAT, no constant) and y (Admitted)
plt.scatter(x1,y, color='C0')
# Don't forget to label your axes!
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('Admitted', fontsize = 20)
plt.show()

# %% [markdown]
# ### Plot with a regression line

# %%
# Create a linear regression on the data in order to estimate the coefficients and be able to plot a regression line
# The data is not linear, so the linear regression doesn't make much sense
x = sm.add_constant(x1)
# I'll call it reg_lin, instead of reg, as we will be dealing with logistic regressions later on
reg_lin = sm.OLS(y,x)
# I'll segment it into regression and fitted regression (results) as I can use the results as an object for some operations
results_lin = reg_lin.fit()

# Create a scatter plot
plt.scatter(x1,y,color = 'C0')
# Plot the regression line. The coefficients are coming from results_lin.params
y_hat = x1*results_lin.params[1]+results_lin.params[0]
plt.plot(x1,y_hat,lw=2.5,color='C8')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('Admitted', fontsize = 20)
plt.show()

# %% [markdown]
# ### Plot a logistic regression curve

# %%
# here we are using a logistic regression; we use the probability
# e^(b_0x_0 + b_1x_1 +...) / 1 + e^(b_0x_0 + b_1x_1 +...) = p(X)
# to transform to odds = p(X)/1-p(X) = e^(b_0x_0 + b_1x_1 +...)
# so that log(odds) = b_0x_0 + b_1x_1 +... for further explanation
# of the softmax function see
# http://willwolf.io/2017/04/19/deriving-the-softmax-from-first-principles/
reg_log = sm.Logit(y,x)
results_log = reg_log.fit()
print(results_log.summary())
# note that mle is max likelihood estimation, that could be gradient
# descent- log likelihood is almost always negative and the smaller
# the better, llnull is the log likelihood of the predicted b_0,
# and the log likelihood  p value is the likelihood of the null
# hypothesis being true (b_i = 0), so small is good. 

def f(x,b0,b1):
    return np.array(np.exp(b0+x*b1) / (1 + np.exp(b0+x*b1)))

f_sorted = np.sort(f(x1,results_log.params[0],results_log.params[1]))
x_sorted = np.sort(np.array(x1))

plt.scatter(x1,y,color='C0')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('Admitted', fontsize = 20)
plt.plot(x_sorted,f_sorted,color='C8')
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.137766
#          Iterations 10
#                            Logit Regression Results
# ...
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      166
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 12 Nov 2018   Pseudo R-squ.:                  0.7992
# Time:                        19:06:31   Log-Likelihood:                -23.145
# converged:                       True   LL-Null:                       -115.26
#                                         LLR p-value:                 5.805e-42
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -69.9128     15.737     -4.443      0.000    -100.756     -39.070
# ...

# %%
# Creating a logit regression (we will discuss this in another notebook)
reg_log = sm.Logit(y,x)
# Fitting the regression
results_log = reg_log.fit()

# Creating a logit function, depending on the input and coefficients
def f(x,b0,b1):
    return np.array(np.exp(b0+x*b1) / (1 + np.exp(b0+x*b1)))

# Sorting the y and x, so we can plot the curve
f_sorted = np.sort(f(x1,results_log.params[0],results_log.params[1]))
x_sorted = np.sort(np.array(x1))
plt.scatter(x1,y,color='C0')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('Admitted', fontsize = 20)
# Plotting the curve
plt.plot(x_sorted,f_sorted,color='C8')
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.137766
#          Iterations 10

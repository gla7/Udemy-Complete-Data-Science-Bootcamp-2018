# %% [markdown]
# # Import the relevant libraries

# %%
import numpy as np

# %% [markdown]
# # Declaring scalars, vectors, and matrices

# %% [markdown]
# ## Scalars

# %%
s = 5

# %%
s
# Out:
# 5

# %% [markdown]
# ## Vectors

# %%
v = np.array([5,-2,4])

# %%
v
# Out:
# array([ 5, -2,  4])

# %% [markdown]
# ## Matrices

# %%
m = np.array([[5,12,6],[-3,0,14]])

# %%
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %% [markdown]
# ## Data types

# %%
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %%
type(m)
# Out:
# numpy.ndarray

# %%
s_array = np.array([5])

# %%
type(s_array)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Data shapes

# %%
m.shape
# Out:
# (2, 3)

# %%
v.shape
# Out:
# (3,)

# %%
s.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-746f4b3ed41f> in <module>()
# ----> 1 s.shape
#
# AttributeError: 'int' object has no attribute 'shape'

# %%
s_array.shape
# Out:
# (1,)

# %% [markdown]
# ## Creating a column vector

# %%
v.reshape(1,3)
# Out:
# array([[ 5, -2,  4]])

# %%
v.reshape(3,1)
# Out:
# array([[ 5],
#        [-2],
#        [ 4]])

# %%
m+s
# Out:
# array([[10, 17, 11],
#        [ 2,  5, 19]])

# %%
m+s_array
# Out:
# array([[10, 17, 11],
#        [ 2,  5, 19]])

# %%
v+s
# Out:
# array([10,  3,  9])

# %%
v
# Out:
# array([ 5, -2,  4])

# %%
v+s_array
# Out:
# array([10,  3,  9])

# %%
m+v
# Out:
# array([[10, 10, 10],
#        [ 2, -2, 18]])
